# %%
import torch
import numpy as np
import yaml
import matplotlib.pyplot as plt
import cudaq
from models import FFNN
from moleculars import get_pyscf_results, MOLECULE_DATA
from vmc_cal import *
from vqe_details import *
from tqdm import trange


def load_config(path="config.yaml"):
    with open(path, 'r') as file:
        return yaml.safe_load(file)


def plot_results(results, seps, config):
    method_name = "FFNN+VQE"
    molecule_name = config['molecule_name']
    basis = MOLECULE_DATA[molecule_name]['basis']
    plt.figure(figsize=(12, 8))
    results_VMC = results.pop(method_name)
    for method, values in results.items():
        plt.plot(seps, values, linestyle='--', label=method)
    energies = [res[0] for res in results_VMC]
    errors = [res[1] for res in results_VMC]
    plt.errorbar(seps, energies, yerr=errors, marker='o', linestyle='-', label=method_name, capsize=5)
    plt.xlabel("Separation (Å)"), plt.ylabel("Energy (Hartree)")
    plt.title(f"{molecule_name} Potential Energy Dissociation Curve ({basis})")
    plt.legend(), plt.grid(True, which='both', linestyles='--', linewidth=0.5)
    plt.tight_layout(), plt.show()


def adjust_lr(initial_lr, epoch, schedule_type, T_max, decay_rate=0.98):
    if schedule_type == "cosine":
        return initial_lr * 0.5 * (1 + np.cos(np.pi * epoch / T_max))
    elif schedule_type == "exp":
        return initial_lr * (decay_rate ** epoch)
    else:
        return initial_lr
    

def run_nqs_sr_update(
    nqs_model, vmc_params, qham_of, n_orbitals, device, 
    best_energy, best_state_dict, patience, start_epoch=0, extra_epochs=10):
    """
    Perform additional local SR updates with early stopping.
    """
    no_improve_count = 0
    for ep in range(extra_epochs):
        lr = adjust_lr(vmc_params['learning_rate'], start_epoch + ep, 
                       schedule_type="cosine", T_max=start_epoch + extra_epochs)

        samples = efficient_parallel_sampler(
            nqs_model, 
            vmc_params['n_samples'] // vmc_params['n_chains'], 
            vmc_params['n_chains'], 
            n_orbitals,
            vmc_params['burn_in_steps'], 
            vmc_params['step_intervals'], 
            device=device
        )

        stochastic_reconfiguration_update(
            nqs_model, samples, qham_of,
            lr=lr,
            reg=vmc_params['sr_regularization'],
            device=device
        )

        eval_local_energies = local_energy_batch(nqs_model, samples, qham_of, device)
        eval_mean = eval_local_energies.mean().item()
        eval_std = eval_local_energies.std().item() / np.sqrt(len(eval_local_energies))

        if ep % 10 == 0:  
            print(f"[SR Update Epoch {ep + 1}] "
                  f"Eval Energy: {eval_mean:.6f} ± {eval_std:.6f} Ha")

        if eval_mean < best_energy:
            best_energy = eval_mean
            best_state_dict = {k: v.clone().detach().cpu() for k, v in nqs_model.state_dict().items()}
            no_improve_count = 0
        else:
            no_improve_count += 1

        if no_improve_count >= patience:
            print(f"[Early Stopping] No improvement for {patience} epochs in SR update.")
            break

    if best_state_dict is not None:
        nqs_model.load_state_dict(best_state_dict)
        print(f"[Step 1b] Restored best SR-updated parameters with energy = {best_energy:.6f} Ha")

    print("[Step 1b] Extra SR update finished.")
    return best_energy, best_state_dict

# %%
if __name__ == '__main__':
    config = load_config()
    hybrid_params = config['hybrid_params']
    molecule_choice = config['molecule_name']
    vmc_params = config['vmc_params']
    ffnn_params = config['ffnn_params']
    hew_params = config['hew_params']

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    # cuda:0, cuda:1
    cudaq.set_target("nvidia")
    print(f"Using PyTorch device: {device}, CUDA-Q target: {cudaq.get_target().name}")

    geom = MOLECULE_DATA[molecule_choice]['geometry']
    curve_config = config['dissociation_curve']
    seps = np.linspace(curve_config['start_separation'], curve_config['end_separation'], curve_config['points'])
    base_dist = np.linalg.norm(np.array(geom[0][1]) - np.array(geom[1][1]))
    scales = seps / base_dist if base_dist > 0 else np.ones_like(seps)

    results = {'HF': [], 'FCI': [], 'CCSD': [], 'CCSD(T)': [], "FFNN+VQE": []}
    
    for i, scale in enumerate(scales):
        label = f"{seps[i]:.3f} Å"
        print(f"\n--- Calculating for {molecule_choice} @ {label} ---")

        (
        mol_pyscf, hf_e, fci_e, ccsd_e, ccsd_t_e, qham_of,
        hcore, eri, nuclear_repulsion_energy, n_orb, n_elec) = get_pyscf_results(molecule_choice, scale)

        mol_geom_for_cudaq = [(str(atom), tuple(pos)) for atom, pos in mol_pyscf.atom]
        molecule_ham, data = cudaq.chemistry.create_molecular_hamiltonian(mol_geom_for_cudaq, MOLECULE_DATA[molecule_choice]['basis'])
        results['HF'].append(hf_e); results['FCI'].append(fci_e); results['CCSD'].append(ccsd_e); results['CCSD(T)'].append(ccsd_t_e)

        print(f"  Hartree-Fock: {hf_e:.6f} Ha")
        print(f"  FCI:          {fci_e:.6f} Ha")
        print(f"  CCSD:         {ccsd_e:.6f} Ha")
        print(f"  CCSD(T):      {ccsd_t_e:.6f} Ha")

        n_orbitals = mol_pyscf.nao_nr() * 2
        n_hidden = int(n_orbitals * ffnn_params['alpha'])
        nqs_model = FFNN(n_orbitals, n_hidden, ffnn_params['n_layers'], device=device)

        # --- HYBRID ALGORITHM WITH FEEDBACK LOOP ---
        
        # Step 1: Initial NQS Pre-training with early stopping
        print(f"[Step 1] Starting NQS pre-training for {hybrid_params['nqs_pretrain_epochs']} epochs...")

        best_energy = float("inf")
        best_state_dict = None
        patience = 100   # stop if no improvement for 100 epochs
        no_improve_count = 0

        for ep in trange(hybrid_params['nqs_pretrain_epochs'], desc="NQS Pre-training"):
            
            lr = adjust_lr(vmc_params['learning_rate'], ep, schedule_type="cosine", T_max=hybrid_params['nqs_pretrain_epochs'])

            samples = efficient_parallel_sampler(
                nqs_model, 
                vmc_params['n_samples'] // vmc_params['n_chains'], 
                vmc_params['n_chains'], 
                n_orbitals,
                vmc_params['burn_in_steps'], 
                vmc_params['step_intervals'], 
                device=device
            )

            stochastic_reconfiguration_update(
                nqs_model, samples, qham_of,
                lr=lr,
                reg=vmc_params['sr_regularization'],
                device=device
            )

            eval_local_energies = local_energy_batch(nqs_model, samples, qham_of, device)
            eval_mean = eval_local_energies.mean().item()
            eval_std = eval_local_energies.std().item() / np.sqrt(len(eval_local_energies))

            if (ep + 1) % 10 == 0:
                print(f"[Epoch {ep + 1}] Eval Energy: {eval_mean:.6f} ± {eval_std:.6f} Ha")

            if eval_mean < best_energy:
                best_energy = eval_mean
                best_state_dict = {k: v.clone().detach().cpu() for k, v in nqs_model.state_dict().items()}
                no_improve_count = 0
            else:
                no_improve_count += 1

            if no_improve_count >= patience:
                print(f"[Early Stopping] No improvement for {patience} epochs. Stopping pre-training.")
                break

        if best_state_dict is not None:
            nqs_model.load_state_dict(best_state_dict)
            print(f"[Step 1] Restored best model parameters with energy = {best_energy:.6f} Ha")
        
        # best_energy, best_state_dict = run_nqs_sr_update(
        #     nqs_model, vmc_params, qham_of, n_orbitals, device, 
        #     best_energy, best_state_dict, patience,
        #     start_epoch=0, extra_epochs=hybrid_params['nqs_pretrain_epochs'])
        
        print("[Step 1] NQS pre-training finished.")
        final_energy = 0.0
        
        # vqe_energy, target_state_vector = run_vqe_fine_tuning(
        #     molecule_ham, nqs_model, n_orbitals, data.n_electrons, hew_params['n_layers'],
        #     vmc_params, qham_of, hybrid_params['vqe_max_iterations'], device
        # )
# Out:
# Using PyTorch device: cuda, CUDA-Q target: nvidia
#
# --- Calculating for LiH @ 0.800 Å ---
#   Hartree-Fock: -7.615770 Ha
#   FCI:          -7.634167 Ha
#   CCSD:         -7.634161 Ha
#   CCSD(T):      -7.634167 Ha
# [Step 1] Starting NQS pre-training for 20 epochs...
# NQS Pre-training:  50%|█████     | 10/20 [00:43<00:45,  4.55s/it]
# [Epoch 10] Eval Energy: -5.273798 ± 0.050212 Ha
# NQS Pre-training: 100%|██████████| 20/20 [01:38<00:00,  4.91s/it]
# [Epoch 20] Eval Energy: -5.559600 ± 0.043975 Ha
# [Step 1] Restored best model parameters with energy = -5.636886 Ha
# [Step 1] NQS pre-training finished.

# %%
# --- [您要新增的程式碼] ---
print("\n[Step 2] Sampling from final trained NQS model to find configurations...")

# 進行一次大規模採樣
final_samples_tensor = efficient_parallel_sampler(
    nqs_model, 
    10,  # 提高樣本數以獲得更準確的統計
    vmc_params['n_chains'], 
    n_orbitals,
    vmc_params['burn_in_steps'], 
    vmc_params['step_intervals'], 
    device=device
)

# 將 PyTorch Tensors 轉換為可 hash 的 tuple，以便計數
samples_list = [tuple(s.cpu().numpy().astype(int)) for s in final_samples_tensor]

from collections import Counter
config_counts = Counter(samples_list)

total_samples = len(samples_list)
print(f"\nFound {len(config_counts)} unique configurations from {total_samples} samples.")
print("--- Top 5 Most Probable Configurations ---")
total_probability_check = 0
config_str_counts = Counter()
for config_tuple, count in config_counts.most_common(len(config_counts)):
    # 將 (1, 1, 0, 0) 這樣的 tuple 轉換為 |1100> 這樣的字串
    # config_str = "".join(map(str, config_tuple))
    probability = (count / total_samples) * 100

    mapped_bits = [("0" if s == -1 else "1") for s in config_tuple]
    config_str = "".join(mapped_bits)
    total_probability_check += probability
    config_str_counts[config_str] += count
    print(f"  Config: |{config_str}>,  Probability: {probability:.4f}%  (Count: {count})")
    
print("total_probability=", total_probability_check)
config_counts = dict(config_str_counts)

print("\n--- [最終的 config_str -> Count 映射字典] ---")
print(config_counts)
number_of_unique_configs = len(config_counts)
print(f"\n字典 'final_config_str_dict' 中總共有 {number_of_unique_configs} 個不重複的項目。")
# Out:
# [Step 2] Sampling from final trained NQS model to find configurations...
#
# Found 1445 unique configurations from 2560 samples.
# --- Top 5 Most Probable Configurations ---
#   Config: |000110110111>,  Probability: 0.3516%  (Count: 9)
#   Config: |001001001111>,  Probability: 0.3516%  (Count: 9)
#   Config: |000111111111>,  Probability: 0.3125%  (Count: 8)
#   Config: |001011110111>,  Probability: 0.3125%  (Count: 8)
#   Config: |000111111101>,  Probability: 0.3125%  (Count: 8)
#   Config: |001110111111>,  Probability: 0.2734%  (Count: 7)
#   Config: |001111001111>,  Probability: 0.2734%  (Count: 7)
#   Config: |001101101001>,  Probability: 0.2734%  (Count: 7)
#   Config: |001001111111>,  Probability: 0.2734%  (Count: 7)
#   Config: |001111000101>,  Probability: 0.2734%  (Count: 7)
#   Config: |001011110011>,  Probability: 0.2734%  (Count: 7)
#   Config: |001110011101>,  Probability: 0.2734%  (Count: 7)
#   Config: |000101110111>,  Probability: 0.2734%  (Count: 7)
#   Config: |001101001111>,  Probability: 0.2734%  (Count: 7)
#   Config: |001111000111>,  Probability: 0.2734%  (Count: 7)
#   Config: |000111101110>,  Probability: 0.2734%  (Count: 7)
#   Config: |000111111001>,  Probability: 0.2734%  (Count: 7)
#   Config: |000111010111>,  Probability: 0.2734%  (Count: 7)
#   Config: |000111101111>,  Probability: 0.2734%  (Count: 7)
#   Config: |001110101111>,  Probability: 0.2734%  (Count: 7)
#   Config: |001100111101>,  Probability: 0.2344%  (Count: 6)
#   Config: |001111110101>,  Probability: 0.2344%  (Count: 6)
#   Config: |000110101111>,  Probability: 0.2344%  (Count: 6)
#   Config: |000101101110>,  Probability: 0.2344%  (Count: 6)
#   Config: |000101101111>,  Probability: 0.2344%  (Count: 6)
#   Config: |001011111111>,  Probability: 0.2344%  (Count: 6)
#   Config: |001111011010>,  Probability: 0.2344%  (Count: 6)
#   Config: |001101011110>,  Probability: 0.2344%  (Count: 6)
#   Config: |000101001111>,  Probability: 0.2344%  (Count: 6)
#   Config: |001110111011>,  Probability: 0.2344%  (Count: 6)
#   Config: |001111010111>,  Probability: 0.2344%  (Count: 6)
#   Config: |001011101111>,  Probability: 0.2344%  (Count: 6)
#   Config: |000111100011>,  Probability: 0.2344%  (Count: 6)
#   Config: |000011101110>,  Probability: 0.2344%  (Count: 6)
#   Config: |001011110110>,  Probability: 0.1953%  (Count: 5)
#   Config: |001101110011>,  Probability: 0.1953%  (Count: 5)
#   Config: |000111111011>,  Probability: 0.1953%  (Count: 5)
#   Config: |001111100111>,  Probability: 0.1953%  (Count: 5)
#   Config: |001100101111>,  Probability: 0.1953%  (Count: 5)
#   Config: |001010110111>,  Probability: 0.1953%  (Count: 5)
#   Config: |001010111111>,  Probability: 0.1953%  (Count: 5)
#   Config: |000111001111>,  Probability: 0.1953%  (Count: 5)
#   Config: |000110011111>,  Probability: 0.1953%  (Count: 5)
#   Config: |001111101110>,  Probability: 0.1953%  (Count: 5)
#   Config: |001101111011>,  Probability: 0.1953%  (Count: 5)
#   Config: |000110001111>,  Probability: 0.1953%  (Count: 5)
#   Config: |001001101110>,  Probability: 0.1953%  (Count: 5)
#   Config: |000111011010>,  Probability: 0.1953%  (Count: 5)
#   Config: |000111110110>,  Probability: 0.1953%  (Count: 5)
#   Config: |001111011110>,  Probability: 0.1953%  (Count: 5)
#   Config: |001101110110>,  Probability: 0.1953%  (Count: 5)
#   Config: |001100101110>,  Probability: 0.1953%  (Count: 5)
#   Config: |000111110111>,  Probability: 0.1953%  (Count: 5)
#   Config: |001101011011>,  Probability: 0.1953%  (Count: 5)
#   Config: |000110011101>,  Probability: 0.1953%  (Count: 5)
#   Config: |001101011101>,  Probability: 0.1953%  (Count: 5)
#   Config: |001101111101>,  Probability: 0.1953%  (Count: 5)
#   Config: |000101111111>,  Probability: 0.1953%  (Count: 5)
#   Config: |000111111110>,  Probability: 0.1953%  (Count: 5)
#   Config: |001111011111>,  Probability: 0.1953%  (Count: 5)
#   Config: |000100111110>,  Probability: 0.1953%  (Count: 5)
#   Config: |000011101011>,  Probability: 0.1953%  (Count: 5)
#   Config: |001111110110>,  Probability: 0.1953%  (Count: 5)
#   Config: |001011010110>,  Probability: 0.1953%  (Count: 5)
#   Config: |001010100111>,  Probability: 0.1953%  (Count: 5)
#   Config: |000101100111>,  Probability: 0.1953%  (Count: 5)
#   Config: |000001101111>,  Probability: 0.1953%  (Count: 5)
#   Config: |001011010111>,  Probability: 0.1953%  (Count: 5)
#   Config: |001000011111>,  Probability: 0.1953%  (Count: 5)
#   Config: |001011101101>,  Probability: 0.1953%  (Count: 5)
#   Config: |000111011110>,  Probability: 0.1953%  (Count: 5)
#   Config: |000011100111>,  Probability: 0.1953%  (Count: 5)
#   Config: |001110110110>,  Probability: 0.1953%  (Count: 5)
#   Config: |001111010101>,  Probability: 0.1953%  (Count: 5)
#   Config: |001010001111>,  Probability: 0.1953%  (Count: 5)
#   Config: |001110011111>,  Probability: 0.1953%  (Count: 5)
#   Config: |010111001101>,  Probability: 0.1562%  (Count: 4)
#   Config: |001011100110>,  Probability: 0.1562%  (Count: 4)
#   Config: |001101110111>,  Probability: 0.1562%  (Count: 4)
#   Config: |001000101111>,  Probability: 0.1562%  (Count: 4)
#   Config: |001100001111>,  Probability: 0.1562%  (Count: 4)
#   Config: |001111001101>,  Probability: 0.1562%  (Count: 4)
#   Config: |000111110101>,  Probability: 0.1562%  (Count: 4)
#   Config: |001111001011>,  Probability: 0.1562%  (Count: 4)
#   Config: |000101010111>,  Probability: 0.1562%  (Count: 4)
#   Config: |001101001110>,  Probability: 0.1562%  (Count: 4)
#   Config: |000011001111>,  Probability: 0.1562%  (Count: 4)
#   Config: |000111011001>,  Probability: 0.1562%  (Count: 4)
#   Config: |001000010111>,  Probability: 0.1562%  (Count: 4)
#   Config: |000110001011>,  Probability: 0.1562%  (Count: 4)
#   Config: |001100011111>,  Probability: 0.1562%  (Count: 4)
#   Config: |001100011110>,  Probability: 0.1562%  (Count: 4)
#   Config: |001001011111>,  Probability: 0.1562%  (Count: 4)
#   Config: |001101010101>,  Probability: 0.1562%  (Count: 4)
#   Config: |000110111001>,  Probability: 0.1562%  (Count: 4)
#   Config: |001110111101>,  Probability: 0.1562%  (Count: 4)
#   Config: |001100111111>,  Probability: 0.1562%  (Count: 4)
#   Config: |000111111100>,  Probability: 0.1562%  (Count: 4)
#   Config: |001011101011>,  Probability: 0.1562%  (Count: 4)
#   Config: |000011000111>,  Probability: 0.1562%  (Count: 4)
#   Config: |000111110011>,  Probability: 0.1562%  (Count: 4)
#   Config: |000110111111>,  Probability: 0.1562%  (Count: 4)
#   Config: |001101111010>,  Probability: 0.1562%  (Count: 4)
#   Config: |001100001110>,  Probability: 0.1562%  (Count: 4)
#   Config: |001110010100>,  Probability: 0.1562%  (Count: 4)
#   Config: |000111100110>,  Probability: 0.1562%  (Count: 4)
#   Config: |001000110100>,  Probability: 0.1562%  (Count: 4)
#   Config: |000001111111>,  Probability: 0.1562%  (Count: 4)
#   Config: |011101100011>,  Probability: 0.1562%  (Count: 4)
#   Config: |001011111110>,  Probability: 0.1562%  (Count: 4)
#   Config: |000010100011>,  Probability: 0.1562%  (Count: 4)
#   Config: |001011001111>,  Probability: 0.1562%  (Count: 4)
#   Config: |000101101011>,  Probability: 0.1562%  (Count: 4)
#   Config: |001111001001>,  Probability: 0.1562%  (Count: 4)
#   Config: |001110011011>,  Probability: 0.1562%  (Count: 4)
#   Config: |000111011101>,  Probability: 0.1562%  (Count: 4)
#   Config: |001001110100>,  Probability: 0.1562%  (Count: 4)
#   Config: |000010111011>,  Probability: 0.1562%  (Count: 4)
#   Config: |001100011101>,  Probability: 0.1562%  (Count: 4)
#   Config: |001111110010>,  Probability: 0.1562%  (Count: 4)
#   Config: |001110010101>,  Probability: 0.1562%  (Count: 4)
#   Config: |000110101011>,  Probability: 0.1562%  (Count: 4)
#   Config: |001110000101>,  Probability: 0.1562%  (Count: 4)
#   Config: |000011111011>,  Probability: 0.1562%  (Count: 4)
#   Config: |000110001001>,  Probability: 0.1562%  (Count: 4)
#   Config: |001010110110>,  Probability: 0.1562%  (Count: 4)
#   Config: |000011111111>,  Probability: 0.1562%  (Count: 4)
#   Config: |000111010110>,  Probability: 0.1562%  (Count: 4)
#   Config: |001110110101>,  Probability: 0.1562%  (Count: 4)
#   Config: |001111111101>,  Probability: 0.1562%  (Count: 4)
#   Config: |000111011100>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110001010>,  Probability: 0.1172%  (Count: 3)
#   Config: |100011111011>,  Probability: 0.1172%  (Count: 3)
#   Config: |001001010111>,  Probability: 0.1172%  (Count: 3)
#   Config: |100011011111>,  Probability: 0.1172%  (Count: 3)
#   Config: |100011111001>,  Probability: 0.1172%  (Count: 3)
#   Config: |011101011111>,  Probability: 0.1172%  (Count: 3)
#   Config: |010110110110>,  Probability: 0.1172%  (Count: 3)
#   Config: |000101111011>,  Probability: 0.1172%  (Count: 3)
#   Config: |001010111011>,  Probability: 0.1172%  (Count: 3)
#   Config: |101000000011>,  Probability: 0.1172%  (Count: 3)
#   Config: |001100001101>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110100011>,  Probability: 0.1172%  (Count: 3)
#   Config: |010001111100>,  Probability: 0.1172%  (Count: 3)
#   Config: |010011111010>,  Probability: 0.1172%  (Count: 3)
#   Config: |001001101011>,  Probability: 0.1172%  (Count: 3)
#   Config: |000001100011>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110101001>,  Probability: 0.1172%  (Count: 3)
#   Config: |001111111111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001101110010>,  Probability: 0.1172%  (Count: 3)
#   Config: |101110011111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001111111011>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110101010>,  Probability: 0.1172%  (Count: 3)
#   Config: |101011001011>,  Probability: 0.1172%  (Count: 3)
#   Config: |001100100101>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110110001>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110100110>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110100111>,  Probability: 0.1172%  (Count: 3)
#   Config: |000110101110>,  Probability: 0.1172%  (Count: 3)
#   Config: |011010110111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001011011110>,  Probability: 0.1172%  (Count: 3)
#   Config: |001100111100>,  Probability: 0.1172%  (Count: 3)
#   Config: |011110010001>,  Probability: 0.1172%  (Count: 3)
#   Config: |001000001011>,  Probability: 0.1172%  (Count: 3)
#   Config: |000100001011>,  Probability: 0.1172%  (Count: 3)
#   Config: |000100110001>,  Probability: 0.1172%  (Count: 3)
#   Config: |001100000101>,  Probability: 0.1172%  (Count: 3)
#   Config: |010101101101>,  Probability: 0.1172%  (Count: 3)
#   Config: |011110111111>,  Probability: 0.1172%  (Count: 3)
#   Config: |101101001011>,  Probability: 0.1172%  (Count: 3)
#   Config: |001101100110>,  Probability: 0.1172%  (Count: 3)
#   Config: |001101010001>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110010111>,  Probability: 0.1172%  (Count: 3)
#   Config: |000100010111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001111010010>,  Probability: 0.1172%  (Count: 3)
#   Config: |000111100010>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110010011>,  Probability: 0.1172%  (Count: 3)
#   Config: |001010011110>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110000111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110101011>,  Probability: 0.1172%  (Count: 3)
#   Config: |001001111011>,  Probability: 0.1172%  (Count: 3)
#   Config: |000101111110>,  Probability: 0.1172%  (Count: 3)
#   Config: |101100011101>,  Probability: 0.1172%  (Count: 3)
#   Config: |010111001001>,  Probability: 0.1172%  (Count: 3)
#   Config: |000101010110>,  Probability: 0.1172%  (Count: 3)
#   Config: |011111001101>,  Probability: 0.1172%  (Count: 3)
#   Config: |000111101001>,  Probability: 0.1172%  (Count: 3)
#   Config: |001100101001>,  Probability: 0.1172%  (Count: 3)
#   Config: |000011110101>,  Probability: 0.1172%  (Count: 3)
#   Config: |000110110010>,  Probability: 0.1172%  (Count: 3)
#   Config: |001111110100>,  Probability: 0.1172%  (Count: 3)
#   Config: |001001011110>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110101101>,  Probability: 0.1172%  (Count: 3)
#   Config: |000010111110>,  Probability: 0.1172%  (Count: 3)
#   Config: |001011000111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001000111111>,  Probability: 0.1172%  (Count: 3)
#   Config: |011010001001>,  Probability: 0.1172%  (Count: 3)
#   Config: |001111101010>,  Probability: 0.1172%  (Count: 3)
#   Config: |001011100011>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110001111>,  Probability: 0.1172%  (Count: 3)
#   Config: |011010100011>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110001000>,  Probability: 0.1172%  (Count: 3)
#   Config: |001000111011>,  Probability: 0.1172%  (Count: 3)
#   Config: |000011011001>,  Probability: 0.1172%  (Count: 3)
#   Config: |001101101110>,  Probability: 0.1172%  (Count: 3)
#   Config: |000001001111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001100000111>,  Probability: 0.1172%  (Count: 3)
#   Config: |000100001110>,  Probability: 0.1172%  (Count: 3)
#   Config: |001100111010>,  Probability: 0.1172%  (Count: 3)
#   Config: |000101110011>,  Probability: 0.1172%  (Count: 3)
#   Config: |001111111100>,  Probability: 0.1172%  (Count: 3)
#   Config: |001111110111>,  Probability: 0.1172%  (Count: 3)
#   Config: |000100110111>,  Probability: 0.1172%  (Count: 3)
#   Config: |000100101111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001111011011>,  Probability: 0.1172%  (Count: 3)
#   Config: |000101100110>,  Probability: 0.1172%  (Count: 3)
#   Config: |000111111000>,  Probability: 0.1172%  (Count: 3)
#   Config: |001001111101>,  Probability: 0.1172%  (Count: 3)
#   Config: |000010100111>,  Probability: 0.1172%  (Count: 3)
#   Config: |000010110101>,  Probability: 0.1172%  (Count: 3)
#   Config: |000011011011>,  Probability: 0.1172%  (Count: 3)
#   Config: |011010111111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001100101101>,  Probability: 0.1172%  (Count: 3)
#   Config: |000001110111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001010011111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110101100>,  Probability: 0.1172%  (Count: 3)
#   Config: |001011001010>,  Probability: 0.1172%  (Count: 3)
#   Config: |001101111110>,  Probability: 0.1172%  (Count: 3)
#   Config: |001010100001>,  Probability: 0.1172%  (Count: 3)
#   Config: |000110110101>,  Probability: 0.1172%  (Count: 3)
#   Config: |000101011111>,  Probability: 0.1172%  (Count: 3)
#   Config: |000000111101>,  Probability: 0.1172%  (Count: 3)
#   Config: |001100000110>,  Probability: 0.1172%  (Count: 3)
#   Config: |001011110100>,  Probability: 0.1172%  (Count: 3)
#   Config: |000111011111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001010001101>,  Probability: 0.1172%  (Count: 3)
#   Config: |001000000111>,  Probability: 0.1172%  (Count: 3)
#   Config: |011000110111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001011000110>,  Probability: 0.1172%  (Count: 3)
#   Config: |011011010111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001001110011>,  Probability: 0.1172%  (Count: 3)
#   Config: |000001111010>,  Probability: 0.1172%  (Count: 3)
#   Config: |001111011001>,  Probability: 0.1172%  (Count: 3)
#   Config: |001101100001>,  Probability: 0.1172%  (Count: 3)
#   Config: |011010111110>,  Probability: 0.1172%  (Count: 3)
#   Config: |000011110011>,  Probability: 0.1172%  (Count: 3)
#   Config: |000011111101>,  Probability: 0.1172%  (Count: 3)
#   Config: |001100111001>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110111110>,  Probability: 0.1172%  (Count: 3)
#   Config: |001101010111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001101011001>,  Probability: 0.1172%  (Count: 3)
#   Config: |000010101111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001111000001>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110011100>,  Probability: 0.1172%  (Count: 3)
#   Config: |000100111011>,  Probability: 0.1172%  (Count: 3)
#   Config: |000101011101>,  Probability: 0.1172%  (Count: 3)
#   Config: |000101101001>,  Probability: 0.1172%  (Count: 3)
#   Config: |001100111011>,  Probability: 0.1172%  (Count: 3)
#   Config: |000010111111>,  Probability: 0.1172%  (Count: 3)
#   Config: |000111110010>,  Probability: 0.1172%  (Count: 3)
#   Config: |001101010011>,  Probability: 0.1172%  (Count: 3)
#   Config: |000111100111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001000111010>,  Probability: 0.1172%  (Count: 3)
#   Config: |001110011110>,  Probability: 0.1172%  (Count: 3)
#   Config: |001011011010>,  Probability: 0.1172%  (Count: 3)
#   Config: |010110101111>,  Probability: 0.1172%  (Count: 3)
#   Config: |000011010110>,  Probability: 0.1172%  (Count: 3)
#   Config: |000011111110>,  Probability: 0.1172%  (Count: 3)
#   Config: |001001100011>,  Probability: 0.1172%  (Count: 3)
#   Config: |000011110111>,  Probability: 0.1172%  (Count: 3)
#   Config: |000011010111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001101100011>,  Probability: 0.1172%  (Count: 3)
#   Config: |001011011111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001100101011>,  Probability: 0.1172%  (Count: 3)
#   Config: |011010001010>,  Probability: 0.1172%  (Count: 3)
#   Config: |001101001011>,  Probability: 0.1172%  (Count: 3)
#   Config: |000000011111>,  Probability: 0.1172%  (Count: 3)
#   Config: |001000011011>,  Probability: 0.0781%  (Count: 2)
#   Config: |011000011100>,  Probability: 0.0781%  (Count: 2)
#   Config: |000110010111>,  Probability: 0.0781%  (Count: 2)
#   Config: |010010111110>,  Probability: 0.0781%  (Count: 2)
#   Config: |010100010110>,  Probability: 0.0781%  (Count: 2)
#   Config: |011101011011>,  Probability: 0.0781%  (Count: 2)
#   Config: |100010110010>,  Probability: 0.0781%  (Count: 2)
#   Config: |001000111110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001110001011>,  Probability: 0.0781%  (Count: 2)
#   Config: |000001010111>,  Probability: 0.0781%  (Count: 2)
#   Config: |011010111010>,  Probability: 0.0781%  (Count: 2)
#   Config: |000111001010>,  Probability: 0.0781%  (Count: 2)
#   Config: |010100101110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001010111110>,  Probability: 0.0781%  (Count: 2)
#   Config: |000101101101>,  Probability: 0.0781%  (Count: 2)
#   Config: |100110100110>,  Probability: 0.0781%  (Count: 2)
#   Config: |000100001111>,  Probability: 0.0781%  (Count: 2)
#   Config: |001011101110>,  Probability: 0.0781%  (Count: 2)
#   Config: |101001111100>,  Probability: 0.0781%  (Count: 2)
#   Config: |100000110111>,  Probability: 0.0781%  (Count: 2)
#   Config: |001100011100>,  Probability: 0.0781%  (Count: 2)
#   Config: |001001000101>,  Probability: 0.0781%  (Count: 2)
#   Config: |011110110001>,  Probability: 0.0781%  (Count: 2)
#   Config: |000011101010>,  Probability: 0.0781%  (Count: 2)
#   Config: |000011000001>,  Probability: 0.0781%  (Count: 2)
#   Config: |001110100100>,  Probability: 0.0781%  (Count: 2)
#   Config: |000110100101>,  Probability: 0.0781%  (Count: 2)
#   Config: |011001010011>,  Probability: 0.0781%  (Count: 2)
#   Config: |000011101101>,  Probability: 0.0781%  (Count: 2)
#   Config: |001100110011>,  Probability: 0.0781%  (Count: 2)
#   Config: |101100111111>,  Probability: 0.0781%  (Count: 2)
#   Config: |101010011001>,  Probability: 0.0781%  (Count: 2)
#   Config: |100111111100>,  Probability: 0.0781%  (Count: 2)
#   Config: |000101011110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001010101111>,  Probability: 0.0781%  (Count: 2)
#   Config: |100010011111>,  Probability: 0.0781%  (Count: 2)
#   Config: |001100100010>,  Probability: 0.0781%  (Count: 2)
#   Config: |000011100110>,  Probability: 0.0781%  (Count: 2)
#   Config: |000101111001>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111001010>,  Probability: 0.0781%  (Count: 2)
#   Config: |001101010110>,  Probability: 0.0781%  (Count: 2)
#   Config: |100111111000>,  Probability: 0.0781%  (Count: 2)
#   Config: |001011010101>,  Probability: 0.0781%  (Count: 2)
#   Config: |001100010010>,  Probability: 0.0781%  (Count: 2)
#   Config: |011100110011>,  Probability: 0.0781%  (Count: 2)
#   Config: |101111110010>,  Probability: 0.0781%  (Count: 2)
#   Config: |011110110111>,  Probability: 0.0781%  (Count: 2)
#   Config: |000001011011>,  Probability: 0.0781%  (Count: 2)
#   Config: |000110010010>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111110001>,  Probability: 0.0781%  (Count: 2)
#   Config: |011101011110>,  Probability: 0.0781%  (Count: 2)
#   Config: |010011110001>,  Probability: 0.0781%  (Count: 2)
#   Config: |011110100111>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111010011>,  Probability: 0.0781%  (Count: 2)
#   Config: |001001101111>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111100101>,  Probability: 0.0781%  (Count: 2)
#   Config: |011110011010>,  Probability: 0.0781%  (Count: 2)
#   Config: |001100101000>,  Probability: 0.0781%  (Count: 2)
#   Config: |001110010110>,  Probability: 0.0781%  (Count: 2)
#   Config: |011100001010>,  Probability: 0.0781%  (Count: 2)
#   Config: |101000100111>,  Probability: 0.0781%  (Count: 2)
#   Config: |000100110110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001101010100>,  Probability: 0.0781%  (Count: 2)
#   Config: |000110001100>,  Probability: 0.0781%  (Count: 2)
#   Config: |001101101101>,  Probability: 0.0781%  (Count: 2)
#   Config: |010100010011>,  Probability: 0.0781%  (Count: 2)
#   Config: |001101111100>,  Probability: 0.0781%  (Count: 2)
#   Config: |000111101000>,  Probability: 0.0781%  (Count: 2)
#   Config: |011000110011>,  Probability: 0.0781%  (Count: 2)
#   Config: |001110110111>,  Probability: 0.0781%  (Count: 2)
#   Config: |000110100110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001110110000>,  Probability: 0.0781%  (Count: 2)
#   Config: |100100111010>,  Probability: 0.0781%  (Count: 2)
#   Config: |000100100100>,  Probability: 0.0781%  (Count: 2)
#   Config: |011011001110>,  Probability: 0.0781%  (Count: 2)
#   Config: |011010111000>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111111001>,  Probability: 0.0781%  (Count: 2)
#   Config: |011011001111>,  Probability: 0.0781%  (Count: 2)
#   Config: |011011110111>,  Probability: 0.0781%  (Count: 2)
#   Config: |000111011011>,  Probability: 0.0781%  (Count: 2)
#   Config: |000010110110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001011111011>,  Probability: 0.0781%  (Count: 2)
#   Config: |000110010101>,  Probability: 0.0781%  (Count: 2)
#   Config: |000110001110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001101100111>,  Probability: 0.0781%  (Count: 2)
#   Config: |110011010011>,  Probability: 0.0781%  (Count: 2)
#   Config: |000110111110>,  Probability: 0.0781%  (Count: 2)
#   Config: |010101011111>,  Probability: 0.0781%  (Count: 2)
#   Config: |001100001010>,  Probability: 0.0781%  (Count: 2)
#   Config: |011000101010>,  Probability: 0.0781%  (Count: 2)
#   Config: |011000010111>,  Probability: 0.0781%  (Count: 2)
#   Config: |000100110010>,  Probability: 0.0781%  (Count: 2)
#   Config: |000101110101>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111100010>,  Probability: 0.0781%  (Count: 2)
#   Config: |001010110011>,  Probability: 0.0781%  (Count: 2)
#   Config: |000000110110>,  Probability: 0.0781%  (Count: 2)
#   Config: |000010011101>,  Probability: 0.0781%  (Count: 2)
#   Config: |101111010101>,  Probability: 0.0781%  (Count: 2)
#   Config: |010110000110>,  Probability: 0.0781%  (Count: 2)
#   Config: |101111110110>,  Probability: 0.0781%  (Count: 2)
#   Config: |011000011111>,  Probability: 0.0781%  (Count: 2)
#   Config: |001011110001>,  Probability: 0.0781%  (Count: 2)
#   Config: |001100111000>,  Probability: 0.0781%  (Count: 2)
#   Config: |000010101110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001001110111>,  Probability: 0.0781%  (Count: 2)
#   Config: |101010101110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001000000011>,  Probability: 0.0781%  (Count: 2)
#   Config: |001110000011>,  Probability: 0.0781%  (Count: 2)
#   Config: |011101001101>,  Probability: 0.0781%  (Count: 2)
#   Config: |101011111001>,  Probability: 0.0781%  (Count: 2)
#   Config: |101111010111>,  Probability: 0.0781%  (Count: 2)
#   Config: |001100010111>,  Probability: 0.0781%  (Count: 2)
#   Config: |001100110100>,  Probability: 0.0781%  (Count: 2)
#   Config: |000001101110>,  Probability: 0.0781%  (Count: 2)
#   Config: |010111100101>,  Probability: 0.0781%  (Count: 2)
#   Config: |000010000110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111100000>,  Probability: 0.0781%  (Count: 2)
#   Config: |010111011010>,  Probability: 0.0781%  (Count: 2)
#   Config: |010100100101>,  Probability: 0.0781%  (Count: 2)
#   Config: |010111000111>,  Probability: 0.0781%  (Count: 2)
#   Config: |000011010101>,  Probability: 0.0781%  (Count: 2)
#   Config: |010110010111>,  Probability: 0.0781%  (Count: 2)
#   Config: |100100011110>,  Probability: 0.0781%  (Count: 2)
#   Config: |000101110110>,  Probability: 0.0781%  (Count: 2)
#   Config: |011111110101>,  Probability: 0.0781%  (Count: 2)
#   Config: |100011011110>,  Probability: 0.0781%  (Count: 2)
#   Config: |100111011010>,  Probability: 0.0781%  (Count: 2)
#   Config: |100101100111>,  Probability: 0.0781%  (Count: 2)
#   Config: |000110111011>,  Probability: 0.0781%  (Count: 2)
#   Config: |001011100001>,  Probability: 0.0781%  (Count: 2)
#   Config: |011011101100>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111100110>,  Probability: 0.0781%  (Count: 2)
#   Config: |000010110111>,  Probability: 0.0781%  (Count: 2)
#   Config: |001001100110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001011001001>,  Probability: 0.0781%  (Count: 2)
#   Config: |001000100111>,  Probability: 0.0781%  (Count: 2)
#   Config: |010110101110>,  Probability: 0.0781%  (Count: 2)
#   Config: |101000011110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001101101011>,  Probability: 0.0781%  (Count: 2)
#   Config: |001011011101>,  Probability: 0.0781%  (Count: 2)
#   Config: |010110100010>,  Probability: 0.0781%  (Count: 2)
#   Config: |010101001011>,  Probability: 0.0781%  (Count: 2)
#   Config: |101100010101>,  Probability: 0.0781%  (Count: 2)
#   Config: |000101111101>,  Probability: 0.0781%  (Count: 2)
#   Config: |000100110011>,  Probability: 0.0781%  (Count: 2)
#   Config: |000110101001>,  Probability: 0.0781%  (Count: 2)
#   Config: |001010101110>,  Probability: 0.0781%  (Count: 2)
#   Config: |011110000111>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111001000>,  Probability: 0.0781%  (Count: 2)
#   Config: |011110101101>,  Probability: 0.0781%  (Count: 2)
#   Config: |000111001000>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111100001>,  Probability: 0.0781%  (Count: 2)
#   Config: |001100110101>,  Probability: 0.0781%  (Count: 2)
#   Config: |101101011101>,  Probability: 0.0781%  (Count: 2)
#   Config: |000001111100>,  Probability: 0.0781%  (Count: 2)
#   Config: |000000111010>,  Probability: 0.0781%  (Count: 2)
#   Config: |000101100101>,  Probability: 0.0781%  (Count: 2)
#   Config: |001101001101>,  Probability: 0.0781%  (Count: 2)
#   Config: |101100011100>,  Probability: 0.0781%  (Count: 2)
#   Config: |010011000110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001011111100>,  Probability: 0.0781%  (Count: 2)
#   Config: |001100100111>,  Probability: 0.0781%  (Count: 2)
#   Config: |101011011011>,  Probability: 0.0781%  (Count: 2)
#   Config: |001110101000>,  Probability: 0.0781%  (Count: 2)
#   Config: |000101001101>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111010110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001100000011>,  Probability: 0.0781%  (Count: 2)
#   Config: |011101010101>,  Probability: 0.0781%  (Count: 2)
#   Config: |100100111100>,  Probability: 0.0781%  (Count: 2)
#   Config: |011011111010>,  Probability: 0.0781%  (Count: 2)
#   Config: |010010111111>,  Probability: 0.0781%  (Count: 2)
#   Config: |101000011010>,  Probability: 0.0781%  (Count: 2)
#   Config: |100111110001>,  Probability: 0.0781%  (Count: 2)
#   Config: |011010000011>,  Probability: 0.0781%  (Count: 2)
#   Config: |001110000110>,  Probability: 0.0781%  (Count: 2)
#   Config: |000100101011>,  Probability: 0.0781%  (Count: 2)
#   Config: |000110011001>,  Probability: 0.0781%  (Count: 2)
#   Config: |011100011111>,  Probability: 0.0781%  (Count: 2)
#   Config: |101011011110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001101001010>,  Probability: 0.0781%  (Count: 2)
#   Config: |001000101011>,  Probability: 0.0781%  (Count: 2)
#   Config: |001001111110>,  Probability: 0.0781%  (Count: 2)
#   Config: |101001001100>,  Probability: 0.0781%  (Count: 2)
#   Config: |011101100111>,  Probability: 0.0781%  (Count: 2)
#   Config: |001101101111>,  Probability: 0.0781%  (Count: 2)
#   Config: |000111111010>,  Probability: 0.0781%  (Count: 2)
#   Config: |001011111010>,  Probability: 0.0781%  (Count: 2)
#   Config: |101011001001>,  Probability: 0.0781%  (Count: 2)
#   Config: |011110011101>,  Probability: 0.0781%  (Count: 2)
#   Config: |001101100101>,  Probability: 0.0781%  (Count: 2)
#   Config: |010110001101>,  Probability: 0.0781%  (Count: 2)
#   Config: |001011101001>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111001110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001101110001>,  Probability: 0.0781%  (Count: 2)
#   Config: |001101011010>,  Probability: 0.0781%  (Count: 2)
#   Config: |001011110010>,  Probability: 0.0781%  (Count: 2)
#   Config: |000010001011>,  Probability: 0.0781%  (Count: 2)
#   Config: |010011101011>,  Probability: 0.0781%  (Count: 2)
#   Config: |100001001110>,  Probability: 0.0781%  (Count: 2)
#   Config: |000100010101>,  Probability: 0.0781%  (Count: 2)
#   Config: |001010100110>,  Probability: 0.0781%  (Count: 2)
#   Config: |101001111110>,  Probability: 0.0781%  (Count: 2)
#   Config: |000100001001>,  Probability: 0.0781%  (Count: 2)
#   Config: |001101100100>,  Probability: 0.0781%  (Count: 2)
#   Config: |001100110110>,  Probability: 0.0781%  (Count: 2)
#   Config: |101001101110>,  Probability: 0.0781%  (Count: 2)
#   Config: |011110010110>,  Probability: 0.0781%  (Count: 2)
#   Config: |000100101110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001101111111>,  Probability: 0.0781%  (Count: 2)
#   Config: |010110101001>,  Probability: 0.0781%  (Count: 2)
#   Config: |001010001011>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111110000>,  Probability: 0.0781%  (Count: 2)
#   Config: |101111100101>,  Probability: 0.0781%  (Count: 2)
#   Config: |001101000011>,  Probability: 0.0781%  (Count: 2)
#   Config: |100111001110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001011110000>,  Probability: 0.0781%  (Count: 2)
#   Config: |101011010110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111101111>,  Probability: 0.0781%  (Count: 2)
#   Config: |000110110110>,  Probability: 0.0781%  (Count: 2)
#   Config: |010110011111>,  Probability: 0.0781%  (Count: 2)
#   Config: |011011011101>,  Probability: 0.0781%  (Count: 2)
#   Config: |000101110010>,  Probability: 0.0781%  (Count: 2)
#   Config: |101110011100>,  Probability: 0.0781%  (Count: 2)
#   Config: |001011010011>,  Probability: 0.0781%  (Count: 2)
#   Config: |100010101111>,  Probability: 0.0781%  (Count: 2)
#   Config: |000011011010>,  Probability: 0.0781%  (Count: 2)
#   Config: |010010111100>,  Probability: 0.0781%  (Count: 2)
#   Config: |001110110100>,  Probability: 0.0781%  (Count: 2)
#   Config: |000111001011>,  Probability: 0.0781%  (Count: 2)
#   Config: |001110111001>,  Probability: 0.0781%  (Count: 2)
#   Config: |000010100010>,  Probability: 0.0781%  (Count: 2)
#   Config: |010010100110>,  Probability: 0.0781%  (Count: 2)
#   Config: |011100000111>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111101101>,  Probability: 0.0781%  (Count: 2)
#   Config: |101010010101>,  Probability: 0.0781%  (Count: 2)
#   Config: |100111010011>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111011101>,  Probability: 0.0781%  (Count: 2)
#   Config: |011110001110>,  Probability: 0.0781%  (Count: 2)
#   Config: |000100111101>,  Probability: 0.0781%  (Count: 2)
#   Config: |000111101011>,  Probability: 0.0781%  (Count: 2)
#   Config: |000011111001>,  Probability: 0.0781%  (Count: 2)
#   Config: |001110110011>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111010001>,  Probability: 0.0781%  (Count: 2)
#   Config: |101111111110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001000110101>,  Probability: 0.0781%  (Count: 2)
#   Config: |000010111101>,  Probability: 0.0781%  (Count: 2)
#   Config: |001011100111>,  Probability: 0.0781%  (Count: 2)
#   Config: |000111100001>,  Probability: 0.0781%  (Count: 2)
#   Config: |000111101101>,  Probability: 0.0781%  (Count: 2)
#   Config: |000101010100>,  Probability: 0.0781%  (Count: 2)
#   Config: |101001100011>,  Probability: 0.0781%  (Count: 2)
#   Config: |100111010111>,  Probability: 0.0781%  (Count: 2)
#   Config: |100000011100>,  Probability: 0.0781%  (Count: 2)
#   Config: |000111010011>,  Probability: 0.0781%  (Count: 2)
#   Config: |111100011110>,  Probability: 0.0781%  (Count: 2)
#   Config: |011001110001>,  Probability: 0.0781%  (Count: 2)
#   Config: |100011110110>,  Probability: 0.0781%  (Count: 2)
#   Config: |011010100111>,  Probability: 0.0781%  (Count: 2)
#   Config: |000110010110>,  Probability: 0.0781%  (Count: 2)
#   Config: |000011010011>,  Probability: 0.0781%  (Count: 2)
#   Config: |001010011011>,  Probability: 0.0781%  (Count: 2)
#   Config: |001011100101>,  Probability: 0.0781%  (Count: 2)
#   Config: |000110100001>,  Probability: 0.0781%  (Count: 2)
#   Config: |000001100111>,  Probability: 0.0781%  (Count: 2)
#   Config: |001000101110>,  Probability: 0.0781%  (Count: 2)
#   Config: |000000101111>,  Probability: 0.0781%  (Count: 2)
#   Config: |011100011010>,  Probability: 0.0781%  (Count: 2)
#   Config: |000001101011>,  Probability: 0.0781%  (Count: 2)
#   Config: |001011011000>,  Probability: 0.0781%  (Count: 2)
#   Config: |000010010110>,  Probability: 0.0781%  (Count: 2)
#   Config: |010111101001>,  Probability: 0.0781%  (Count: 2)
#   Config: |100011101001>,  Probability: 0.0781%  (Count: 2)
#   Config: |000010001111>,  Probability: 0.0781%  (Count: 2)
#   Config: |000100110101>,  Probability: 0.0781%  (Count: 2)
#   Config: |001010011001>,  Probability: 0.0781%  (Count: 2)
#   Config: |010111110011>,  Probability: 0.0781%  (Count: 2)
#   Config: |100010111011>,  Probability: 0.0781%  (Count: 2)
#   Config: |001111101011>,  Probability: 0.0781%  (Count: 2)
#   Config: |101001100110>,  Probability: 0.0781%  (Count: 2)
#   Config: |011000111111>,  Probability: 0.0781%  (Count: 2)
#   Config: |001011110101>,  Probability: 0.0781%  (Count: 2)
#   Config: |100110001111>,  Probability: 0.0781%  (Count: 2)
#   Config: |000110101101>,  Probability: 0.0781%  (Count: 2)
#   Config: |000110011011>,  Probability: 0.0781%  (Count: 2)
#   Config: |111100101010>,  Probability: 0.0781%  (Count: 2)
#   Config: |101011000110>,  Probability: 0.0781%  (Count: 2)
#   Config: |010000111110>,  Probability: 0.0781%  (Count: 2)
#   Config: |011010011010>,  Probability: 0.0781%  (Count: 2)
#   Config: |101111010011>,  Probability: 0.0781%  (Count: 2)
#   Config: |101011101000>,  Probability: 0.0781%  (Count: 2)
#   Config: |001001111001>,  Probability: 0.0781%  (Count: 2)
#   Config: |011001100110>,  Probability: 0.0781%  (Count: 2)
#   Config: |001110011001>,  Probability: 0.0781%  (Count: 2)
#   Config: |110110001111>,  Probability: 0.0781%  (Count: 2)
#   Config: |110010110010>,  Probability: 0.0391%  (Count: 1)
#   Config: |000000010110>,  Probability: 0.0391%  (Count: 1)
#   Config: |011011111100>,  Probability: 0.0391%  (Count: 1)
#   Config: |011010100101>,  Probability: 0.0391%  (Count: 1)
#   Config: |011111100101>,  Probability: 0.0391%  (Count: 1)
#   Config: |011100011000>,  Probability: 0.0391%  (Count: 1)
#   Config: |011101110111>,  Probability: 0.0391%  (Count: 1)
#   Config: |101111110000>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001101101>,  Probability: 0.0391%  (Count: 1)
#   Config: |011011011010>,  Probability: 0.0391%  (Count: 1)
#   Config: |100100110011>,  Probability: 0.0391%  (Count: 1)
#   Config: |010011110111>,  Probability: 0.0391%  (Count: 1)
#   Config: |010010111001>,  Probability: 0.0391%  (Count: 1)
#   Config: |001100100110>,  Probability: 0.0391%  (Count: 1)
#   Config: |111100010101>,  Probability: 0.0391%  (Count: 1)
#   Config: |000001000001>,  Probability: 0.0391%  (Count: 1)
#   Config: |011101100101>,  Probability: 0.0391%  (Count: 1)
#   Config: |001010000000>,  Probability: 0.0391%  (Count: 1)
#   Config: |101101111110>,  Probability: 0.0391%  (Count: 1)
#   Config: |000101111000>,  Probability: 0.0391%  (Count: 1)
#   Config: |011111111010>,  Probability: 0.0391%  (Count: 1)
#   Config: |001110010010>,  Probability: 0.0391%  (Count: 1)
#   Config: |010101111101>,  Probability: 0.0391%  (Count: 1)
#   Config: |010100011110>,  Probability: 0.0391%  (Count: 1)
#   Config: |101010001000>,  Probability: 0.0391%  (Count: 1)
#   Config: |010010010000>,  Probability: 0.0391%  (Count: 1)
#   Config: |010001001101>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001011011>,  Probability: 0.0391%  (Count: 1)
#   Config: |000101101100>,  Probability: 0.0391%  (Count: 1)
#   Config: |100100110101>,  Probability: 0.0391%  (Count: 1)
#   Config: |010010100011>,  Probability: 0.0391%  (Count: 1)
#   Config: |010101110011>,  Probability: 0.0391%  (Count: 1)
#   Config: |110001110100>,  Probability: 0.0391%  (Count: 1)
#   Config: |100110100101>,  Probability: 0.0391%  (Count: 1)
#   Config: |100100100100>,  Probability: 0.0391%  (Count: 1)
#   Config: |000111011000>,  Probability: 0.0391%  (Count: 1)
#   Config: |000011110110>,  Probability: 0.0391%  (Count: 1)
#   Config: |101001100111>,  Probability: 0.0391%  (Count: 1)
#   Config: |111000110101>,  Probability: 0.0391%  (Count: 1)
#   Config: |011010001000>,  Probability: 0.0391%  (Count: 1)
#   Config: |010110111110>,  Probability: 0.0391%  (Count: 1)
#   Config: |011100111011>,  Probability: 0.0391%  (Count: 1)
#   Config: |000001011010>,  Probability: 0.0391%  (Count: 1)
#   Config: |011111000000>,  Probability: 0.0391%  (Count: 1)
#   Config: |001011001110>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001101001>,  Probability: 0.0391%  (Count: 1)
#   Config: |010111110110>,  Probability: 0.0391%  (Count: 1)
#   Config: |010101000001>,  Probability: 0.0391%  (Count: 1)
#   Config: |100111001000>,  Probability: 0.0391%  (Count: 1)
#   Config: |001011100010>,  Probability: 0.0391%  (Count: 1)
#   Config: |101011111011>,  Probability: 0.0391%  (Count: 1)
#   Config: |001010111000>,  Probability: 0.0391%  (Count: 1)
#   Config: |011110100101>,  Probability: 0.0391%  (Count: 1)
#   Config: |011101000111>,  Probability: 0.0391%  (Count: 1)
#   Config: |101110000110>,  Probability: 0.0391%  (Count: 1)
#   Config: |101110111110>,  Probability: 0.0391%  (Count: 1)
#   Config: |101011000011>,  Probability: 0.0391%  (Count: 1)
#   Config: |010100010111>,  Probability: 0.0391%  (Count: 1)
#   Config: |000011101001>,  Probability: 0.0391%  (Count: 1)
#   Config: |011110010010>,  Probability: 0.0391%  (Count: 1)
#   Config: |011010000010>,  Probability: 0.0391%  (Count: 1)
#   Config: |001000100000>,  Probability: 0.0391%  (Count: 1)
#   Config: |101011110001>,  Probability: 0.0391%  (Count: 1)
#   Config: |011100100111>,  Probability: 0.0391%  (Count: 1)
#   Config: |000110000010>,  Probability: 0.0391%  (Count: 1)
#   Config: |001011111000>,  Probability: 0.0391%  (Count: 1)
#   Config: |010110001110>,  Probability: 0.0391%  (Count: 1)
#   Config: |010101011100>,  Probability: 0.0391%  (Count: 1)
#   Config: |011110011111>,  Probability: 0.0391%  (Count: 1)
#   Config: |100111101101>,  Probability: 0.0391%  (Count: 1)
#   Config: |100110010110>,  Probability: 0.0391%  (Count: 1)
#   Config: |000010100001>,  Probability: 0.0391%  (Count: 1)
#   Config: |100111011001>,  Probability: 0.0391%  (Count: 1)
#   Config: |000010011111>,  Probability: 0.0391%  (Count: 1)
#   Config: |001011011001>,  Probability: 0.0391%  (Count: 1)
#   Config: |101101100101>,  Probability: 0.0391%  (Count: 1)
#   Config: |011110110100>,  Probability: 0.0391%  (Count: 1)
#   Config: |001000111001>,  Probability: 0.0391%  (Count: 1)
#   Config: |101110010110>,  Probability: 0.0391%  (Count: 1)
#   Config: |011101010011>,  Probability: 0.0391%  (Count: 1)
#   Config: |000000111100>,  Probability: 0.0391%  (Count: 1)
#   Config: |000001110011>,  Probability: 0.0391%  (Count: 1)
#   Config: |100011011101>,  Probability: 0.0391%  (Count: 1)
#   Config: |010000000101>,  Probability: 0.0391%  (Count: 1)
#   Config: |100001111110>,  Probability: 0.0391%  (Count: 1)
#   Config: |011001111100>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001011100>,  Probability: 0.0391%  (Count: 1)
#   Config: |010111100111>,  Probability: 0.0391%  (Count: 1)
#   Config: |011001100101>,  Probability: 0.0391%  (Count: 1)
#   Config: |011101111110>,  Probability: 0.0391%  (Count: 1)
#   Config: |000010011000>,  Probability: 0.0391%  (Count: 1)
#   Config: |011000111101>,  Probability: 0.0391%  (Count: 1)
#   Config: |010010101010>,  Probability: 0.0391%  (Count: 1)
#   Config: |000001000111>,  Probability: 0.0391%  (Count: 1)
#   Config: |000110110011>,  Probability: 0.0391%  (Count: 1)
#   Config: |001100011011>,  Probability: 0.0391%  (Count: 1)
#   Config: |101011100111>,  Probability: 0.0391%  (Count: 1)
#   Config: |011111111011>,  Probability: 0.0391%  (Count: 1)
#   Config: |101010001100>,  Probability: 0.0391%  (Count: 1)
#   Config: |010010000011>,  Probability: 0.0391%  (Count: 1)
#   Config: |100100011011>,  Probability: 0.0391%  (Count: 1)
#   Config: |010101011001>,  Probability: 0.0391%  (Count: 1)
#   Config: |101010100011>,  Probability: 0.0391%  (Count: 1)
#   Config: |100101100100>,  Probability: 0.0391%  (Count: 1)
#   Config: |011110101100>,  Probability: 0.0391%  (Count: 1)
#   Config: |101011110110>,  Probability: 0.0391%  (Count: 1)
#   Config: |100101100000>,  Probability: 0.0391%  (Count: 1)
#   Config: |100101100011>,  Probability: 0.0391%  (Count: 1)
#   Config: |000000111000>,  Probability: 0.0391%  (Count: 1)
#   Config: |111011010110>,  Probability: 0.0391%  (Count: 1)
#   Config: |010110000111>,  Probability: 0.0391%  (Count: 1)
#   Config: |011100100101>,  Probability: 0.0391%  (Count: 1)
#   Config: |000100000101>,  Probability: 0.0391%  (Count: 1)
#   Config: |000001100110>,  Probability: 0.0391%  (Count: 1)
#   Config: |100001110001>,  Probability: 0.0391%  (Count: 1)
#   Config: |000010010111>,  Probability: 0.0391%  (Count: 1)
#   Config: |011100101011>,  Probability: 0.0391%  (Count: 1)
#   Config: |011011100111>,  Probability: 0.0391%  (Count: 1)
#   Config: |011101011100>,  Probability: 0.0391%  (Count: 1)
#   Config: |011011011011>,  Probability: 0.0391%  (Count: 1)
#   Config: |000101001110>,  Probability: 0.0391%  (Count: 1)
#   Config: |111111100011>,  Probability: 0.0391%  (Count: 1)
#   Config: |011100100011>,  Probability: 0.0391%  (Count: 1)
#   Config: |000111101100>,  Probability: 0.0391%  (Count: 1)
#   Config: |010111001010>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001000110>,  Probability: 0.0391%  (Count: 1)
#   Config: |001010101000>,  Probability: 0.0391%  (Count: 1)
#   Config: |010110111011>,  Probability: 0.0391%  (Count: 1)
#   Config: |101110111000>,  Probability: 0.0391%  (Count: 1)
#   Config: |011011011001>,  Probability: 0.0391%  (Count: 1)
#   Config: |111101011001>,  Probability: 0.0391%  (Count: 1)
#   Config: |010100110101>,  Probability: 0.0391%  (Count: 1)
#   Config: |001101100010>,  Probability: 0.0391%  (Count: 1)
#   Config: |101101110101>,  Probability: 0.0391%  (Count: 1)
#   Config: |111100111010>,  Probability: 0.0391%  (Count: 1)
#   Config: |000100100110>,  Probability: 0.0391%  (Count: 1)
#   Config: |000011100100>,  Probability: 0.0391%  (Count: 1)
#   Config: |110110101110>,  Probability: 0.0391%  (Count: 1)
#   Config: |101110011011>,  Probability: 0.0391%  (Count: 1)
#   Config: |100101101010>,  Probability: 0.0391%  (Count: 1)
#   Config: |000110000111>,  Probability: 0.0391%  (Count: 1)
#   Config: |011011101110>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001100101>,  Probability: 0.0391%  (Count: 1)
#   Config: |101010001001>,  Probability: 0.0391%  (Count: 1)
#   Config: |101010000111>,  Probability: 0.0391%  (Count: 1)
#   Config: |111111100010>,  Probability: 0.0391%  (Count: 1)
#   Config: |010110011110>,  Probability: 0.0391%  (Count: 1)
#   Config: |010111100011>,  Probability: 0.0391%  (Count: 1)
#   Config: |011100111110>,  Probability: 0.0391%  (Count: 1)
#   Config: |101101010111>,  Probability: 0.0391%  (Count: 1)
#   Config: |011010010011>,  Probability: 0.0391%  (Count: 1)
#   Config: |101011011010>,  Probability: 0.0391%  (Count: 1)
#   Config: |011111011000>,  Probability: 0.0391%  (Count: 1)
#   Config: |001110001100>,  Probability: 0.0391%  (Count: 1)
#   Config: |001000101101>,  Probability: 0.0391%  (Count: 1)
#   Config: |001110111010>,  Probability: 0.0391%  (Count: 1)
#   Config: |001101000000>,  Probability: 0.0391%  (Count: 1)
#   Config: |101111110111>,  Probability: 0.0391%  (Count: 1)
#   Config: |100011110011>,  Probability: 0.0391%  (Count: 1)
#   Config: |011000111110>,  Probability: 0.0391%  (Count: 1)
#   Config: |101011101101>,  Probability: 0.0391%  (Count: 1)
#   Config: |011101101010>,  Probability: 0.0391%  (Count: 1)
#   Config: |001100111110>,  Probability: 0.0391%  (Count: 1)
#   Config: |000001110101>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001010100>,  Probability: 0.0391%  (Count: 1)
#   Config: |000011001100>,  Probability: 0.0391%  (Count: 1)
#   Config: |101011111101>,  Probability: 0.0391%  (Count: 1)
#   Config: |100100110111>,  Probability: 0.0391%  (Count: 1)
#   Config: |000110111101>,  Probability: 0.0391%  (Count: 1)
#   Config: |011011111000>,  Probability: 0.0391%  (Count: 1)
#   Config: |011110101111>,  Probability: 0.0391%  (Count: 1)
#   Config: |010111101011>,  Probability: 0.0391%  (Count: 1)
#   Config: |000000100110>,  Probability: 0.0391%  (Count: 1)
#   Config: |010000111010>,  Probability: 0.0391%  (Count: 1)
#   Config: |010111110111>,  Probability: 0.0391%  (Count: 1)
#   Config: |101111111001>,  Probability: 0.0391%  (Count: 1)
#   Config: |011011100101>,  Probability: 0.0391%  (Count: 1)
#   Config: |011011001001>,  Probability: 0.0391%  (Count: 1)
#   Config: |000110010000>,  Probability: 0.0391%  (Count: 1)
#   Config: |101111000111>,  Probability: 0.0391%  (Count: 1)
#   Config: |111011001101>,  Probability: 0.0391%  (Count: 1)
#   Config: |001101111000>,  Probability: 0.0391%  (Count: 1)
#   Config: |101000111011>,  Probability: 0.0391%  (Count: 1)
#   Config: |011001010111>,  Probability: 0.0391%  (Count: 1)
#   Config: |001010100101>,  Probability: 0.0391%  (Count: 1)
#   Config: |001101110101>,  Probability: 0.0391%  (Count: 1)
#   Config: |011111101101>,  Probability: 0.0391%  (Count: 1)
#   Config: |010000001101>,  Probability: 0.0391%  (Count: 1)
#   Config: |001101000111>,  Probability: 0.0391%  (Count: 1)
#   Config: |000001001110>,  Probability: 0.0391%  (Count: 1)
#   Config: |010110110001>,  Probability: 0.0391%  (Count: 1)
#   Config: |100110111101>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001111000>,  Probability: 0.0391%  (Count: 1)
#   Config: |000100111111>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001011101>,  Probability: 0.0391%  (Count: 1)
#   Config: |101101101101>,  Probability: 0.0391%  (Count: 1)
#   Config: |101000101110>,  Probability: 0.0391%  (Count: 1)
#   Config: |001011011011>,  Probability: 0.0391%  (Count: 1)
#   Config: |010001101111>,  Probability: 0.0391%  (Count: 1)
#   Config: |011110100100>,  Probability: 0.0391%  (Count: 1)
#   Config: |101101100011>,  Probability: 0.0391%  (Count: 1)
#   Config: |011011111110>,  Probability: 0.0391%  (Count: 1)
#   Config: |101000010011>,  Probability: 0.0391%  (Count: 1)
#   Config: |110001010111>,  Probability: 0.0391%  (Count: 1)
#   Config: |010100000111>,  Probability: 0.0391%  (Count: 1)
#   Config: |000001010101>,  Probability: 0.0391%  (Count: 1)
#   Config: |001101010010>,  Probability: 0.0391%  (Count: 1)
#   Config: |101000010110>,  Probability: 0.0391%  (Count: 1)
#   Config: |111101110111>,  Probability: 0.0391%  (Count: 1)
#   Config: |001111101001>,  Probability: 0.0391%  (Count: 1)
#   Config: |001111001100>,  Probability: 0.0391%  (Count: 1)
#   Config: |001011000101>,  Probability: 0.0391%  (Count: 1)
#   Config: |101101110011>,  Probability: 0.0391%  (Count: 1)
#   Config: |111100000011>,  Probability: 0.0391%  (Count: 1)
#   Config: |010101100111>,  Probability: 0.0391%  (Count: 1)
#   Config: |011010101111>,  Probability: 0.0391%  (Count: 1)
#   Config: |011100101001>,  Probability: 0.0391%  (Count: 1)
#   Config: |001010110101>,  Probability: 0.0391%  (Count: 1)
#   Config: |010000010100>,  Probability: 0.0391%  (Count: 1)
#   Config: |001010010110>,  Probability: 0.0391%  (Count: 1)
#   Config: |000010101010>,  Probability: 0.0391%  (Count: 1)
#   Config: |011010111001>,  Probability: 0.0391%  (Count: 1)
#   Config: |111110001011>,  Probability: 0.0391%  (Count: 1)
#   Config: |011110000110>,  Probability: 0.0391%  (Count: 1)
#   Config: |101110000001>,  Probability: 0.0391%  (Count: 1)
#   Config: |110000110011>,  Probability: 0.0391%  (Count: 1)
# ...
#   Config: |000000011100>,  Probability: 0.0391%  (Count: 1)
#   Config: |100000001101>,  Probability: 0.0391%  (Count: 1)
#   Config: |001011000100>,  Probability: 0.0391%  (Count: 1)
#   Config: |000000101100>,  Probability: 0.0391%  (Count: 1)
#   Config: |000111000100>,  Probability: 0.0391%  (Count: 1)
#   Config: |011001010000>,  Probability: 0.0391%  (Count: 1)
#   Config: |111001001000>,  Probability: 0.0391%  (Count: 1)
#   Config: |100011110101>,  Probability: 0.0391%  (Count: 1)
#   Config: |100111100011>,  Probability: 0.0391%  (Count: 1)
#   Config: |111111011001>,  Probability: 0.0391%  (Count: 1)
#   Config: |000101000110>,  Probability: 0.0391%  (Count: 1)
#   Config: |100100011111>,  Probability: 0.0391%  (Count: 1)
#   Config: |000011101111>,  Probability: 0.0391%  (Count: 1)
#   Config: |010001010111>,  Probability: 0.0391%  (Count: 1)
#   Config: |011001011100>,  Probability: 0.0391%  (Count: 1)
#   Config: |010010001101>,  Probability: 0.0391%  (Count: 1)
#   Config: |011101000110>,  Probability: 0.0391%  (Count: 1)
#   Config: |011001101010>,  Probability: 0.0391%  (Count: 1)
#   Config: |101101111001>,  Probability: 0.0391%  (Count: 1)
#   Config: |000000011001>,  Probability: 0.0391%  (Count: 1)
#   Config: |000000111111>,  Probability: 0.0391%  (Count: 1)
#   Config: |100100111111>,  Probability: 0.0391%  (Count: 1)
#   Config: |001110100101>,  Probability: 0.0391%  (Count: 1)
#   Config: |100111011111>,  Probability: 0.0391%  (Count: 1)
#   Config: |100011010001>,  Probability: 0.0391%  (Count: 1)
#   Config: |001110001001>,  Probability: 0.0391%  (Count: 1)
#   Config: |001111000000>,  Probability: 0.0391%  (Count: 1)
#   Config: |101010100110>,  Probability: 0.0391%  (Count: 1)
#   Config: |011111111111>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001010010>,  Probability: 0.0391%  (Count: 1)
#   Config: |111000000010>,  Probability: 0.0391%  (Count: 1)
#   Config: |111100110000>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001001100>,  Probability: 0.0391%  (Count: 1)
#   Config: |100000111001>,  Probability: 0.0391%  (Count: 1)
#   Config: |000010011110>,  Probability: 0.0391%  (Count: 1)
#   Config: |101111100010>,  Probability: 0.0391%  (Count: 1)
#   Config: |010010110011>,  Probability: 0.0391%  (Count: 1)
#   Config: |011011111111>,  Probability: 0.0391%  (Count: 1)
#   Config: |010100110001>,  Probability: 0.0391%  (Count: 1)
#   Config: |010001011111>,  Probability: 0.0391%  (Count: 1)
#   Config: |011000101101>,  Probability: 0.0391%  (Count: 1)
#   Config: |100111001011>,  Probability: 0.0391%  (Count: 1)
#   Config: |010111101111>,  Probability: 0.0391%  (Count: 1)
#   Config: |101111010001>,  Probability: 0.0391%  (Count: 1)
#   Config: |000101101010>,  Probability: 0.0391%  (Count: 1)
#   Config: |010010000101>,  Probability: 0.0391%  (Count: 1)
#   Config: |011011110010>,  Probability: 0.0391%  (Count: 1)
#   Config: |000100011101>,  Probability: 0.0391%  (Count: 1)
#   Config: |100100101110>,  Probability: 0.0391%  (Count: 1)
#   Config: |011110001111>,  Probability: 0.0391%  (Count: 1)
#   Config: |100011001101>,  Probability: 0.0391%  (Count: 1)
#   Config: |011101110011>,  Probability: 0.0391%  (Count: 1)
#   Config: |011001000010>,  Probability: 0.0391%  (Count: 1)
#   Config: |100011010110>,  Probability: 0.0391%  (Count: 1)
#   Config: |110011111011>,  Probability: 0.0391%  (Count: 1)
#   Config: |001000001111>,  Probability: 0.0391%  (Count: 1)
#   Config: |000011100101>,  Probability: 0.0391%  (Count: 1)
#   Config: |011100100010>,  Probability: 0.0391%  (Count: 1)
#   Config: |000111110000>,  Probability: 0.0391%  (Count: 1)
#   Config: |101010111011>,  Probability: 0.0391%  (Count: 1)
#   Config: |010110011011>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001010011>,  Probability: 0.0391%  (Count: 1)
#   Config: |000111101010>,  Probability: 0.0391%  (Count: 1)
#   Config: |001110101110>,  Probability: 0.0391%  (Count: 1)
#   Config: |001010110000>,  Probability: 0.0391%  (Count: 1)
#   Config: |111000001111>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001001101>,  Probability: 0.0391%  (Count: 1)
#   Config: |100101111111>,  Probability: 0.0391%  (Count: 1)
#   Config: |100000000101>,  Probability: 0.0391%  (Count: 1)
#   Config: |000010110100>,  Probability: 0.0391%  (Count: 1)
#   Config: |101010011011>,  Probability: 0.0391%  (Count: 1)
#   Config: |000110001010>,  Probability: 0.0391%  (Count: 1)
#   Config: |000101100100>,  Probability: 0.0391%  (Count: 1)
#   Config: |011010001101>,  Probability: 0.0391%  (Count: 1)
#   Config: |010001011110>,  Probability: 0.0391%  (Count: 1)
#   Config: |100000011011>,  Probability: 0.0391%  (Count: 1)
#   Config: |101110100101>,  Probability: 0.0391%  (Count: 1)
#   Config: |010011101110>,  Probability: 0.0391%  (Count: 1)
#   Config: |001000001001>,  Probability: 0.0391%  (Count: 1)
#   Config: |001000001110>,  Probability: 0.0391%  (Count: 1)
#   Config: |000010010010>,  Probability: 0.0391%  (Count: 1)
#   Config: |010001010000>,  Probability: 0.0391%  (Count: 1)
#   Config: |000011011100>,  Probability: 0.0391%  (Count: 1)
#   Config: |111110010111>,  Probability: 0.0391%  (Count: 1)
#   Config: |101011101001>,  Probability: 0.0391%  (Count: 1)
#   Config: |100001001011>,  Probability: 0.0391%  (Count: 1)
#   Config: |011011000101>,  Probability: 0.0391%  (Count: 1)
#   Config: |100010111001>,  Probability: 0.0391%  (Count: 1)
#   Config: |000000001110>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001000011>,  Probability: 0.0391%  (Count: 1)
#   Config: |101111110101>,  Probability: 0.0391%  (Count: 1)
#   Config: |011011000011>,  Probability: 0.0391%  (Count: 1)
#   Config: |100110100001>,  Probability: 0.0391%  (Count: 1)
#   Config: |000010100000>,  Probability: 0.0391%  (Count: 1)
#   Config: |011011000000>,  Probability: 0.0391%  (Count: 1)
#   Config: |010011101010>,  Probability: 0.0391%  (Count: 1)
#   Config: |011110010000>,  Probability: 0.0391%  (Count: 1)
#   Config: |101001110001>,  Probability: 0.0391%  (Count: 1)
#   Config: |100101011110>,  Probability: 0.0391%  (Count: 1)
#   Config: |000010001000>,  Probability: 0.0391%  (Count: 1)
#   Config: |110000011100>,  Probability: 0.0391%  (Count: 1)
#   Config: |010010011011>,  Probability: 0.0391%  (Count: 1)
#   Config: |100101001000>,  Probability: 0.0391%  (Count: 1)
#   Config: |100110011101>,  Probability: 0.0391%  (Count: 1)
#   Config: |011110111001>,  Probability: 0.0391%  (Count: 1)
#   Config: |000111000010>,  Probability: 0.0391%  (Count: 1)
#   Config: |001011101010>,  Probability: 0.0391%  (Count: 1)
#   Config: |000100010110>,  Probability: 0.0391%  (Count: 1)
#   Config: |011010101001>,  Probability: 0.0391%  (Count: 1)
#   Config: |101100110111>,  Probability: 0.0391%  (Count: 1)
#   Config: |100010001101>,  Probability: 0.0391%  (Count: 1)
#   Config: |101011011100>,  Probability: 0.0391%  (Count: 1)
#   Config: |000110100111>,  Probability: 0.0391%  (Count: 1)
#   Config: |011111111100>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001101100>,  Probability: 0.0391%  (Count: 1)
#   Config: |010000100010>,  Probability: 0.0391%  (Count: 1)
#   Config: |000101010011>,  Probability: 0.0391%  (Count: 1)
#   Config: |010101111010>,  Probability: 0.0391%  (Count: 1)
#   Config: |011011100110>,  Probability: 0.0391%  (Count: 1)
#   Config: |110000101110>,  Probability: 0.0391%  (Count: 1)
#   Config: |101110110111>,  Probability: 0.0391%  (Count: 1)
#   Config: |011110101110>,  Probability: 0.0391%  (Count: 1)
#   Config: |101110111101>,  Probability: 0.0391%  (Count: 1)
#   Config: |001011000000>,  Probability: 0.0391%  (Count: 1)
#   Config: |010101001000>,  Probability: 0.0391%  (Count: 1)
#   Config: |000101011010>,  Probability: 0.0391%  (Count: 1)
#   Config: |101111101101>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001001001>,  Probability: 0.0391%  (Count: 1)
#   Config: |000101100011>,  Probability: 0.0391%  (Count: 1)
#   Config: |001011111101>,  Probability: 0.0391%  (Count: 1)
#   Config: |101110101101>,  Probability: 0.0391%  (Count: 1)
#   Config: |000010111001>,  Probability: 0.0391%  (Count: 1)
#   Config: |100011011011>,  Probability: 0.0391%  (Count: 1)
#   Config: |011101011010>,  Probability: 0.0391%  (Count: 1)
#   Config: |000000101011>,  Probability: 0.0391%  (Count: 1)
#   Config: |000000100111>,  Probability: 0.0391%  (Count: 1)
#   Config: |110010001111>,  Probability: 0.0391%  (Count: 1)
#   Config: |100101000011>,  Probability: 0.0391%  (Count: 1)
#   Config: |010101001111>,  Probability: 0.0391%  (Count: 1)
#   Config: |011101111001>,  Probability: 0.0391%  (Count: 1)
#   Config: |011110101001>,  Probability: 0.0391%  (Count: 1)
#   Config: |001000000010>,  Probability: 0.0391%  (Count: 1)
#   Config: |100100000010>,  Probability: 0.0391%  (Count: 1)
#   Config: |100100011101>,  Probability: 0.0391%  (Count: 1)
#   Config: |000110011000>,  Probability: 0.0391%  (Count: 1)
#   Config: |101101011010>,  Probability: 0.0391%  (Count: 1)
#   Config: |111011011110>,  Probability: 0.0391%  (Count: 1)
#   Config: |011111110001>,  Probability: 0.0391%  (Count: 1)
#   Config: |011001111101>,  Probability: 0.0391%  (Count: 1)
#   Config: |010111010001>,  Probability: 0.0391%  (Count: 1)
#   Config: |000011000011>,  Probability: 0.0391%  (Count: 1)
#   Config: |011000101110>,  Probability: 0.0391%  (Count: 1)
#   Config: |100111010101>,  Probability: 0.0391%  (Count: 1)
#   Config: |001100100001>,  Probability: 0.0391%  (Count: 1)
#   Config: |100001111001>,  Probability: 0.0391%  (Count: 1)
#   Config: |000110111100>,  Probability: 0.0391%  (Count: 1)
#   Config: |101010001111>,  Probability: 0.0391%  (Count: 1)
#   Config: |011010001110>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001110000>,  Probability: 0.0391%  (Count: 1)
#   Config: |110001111101>,  Probability: 0.0391%  (Count: 1)
#   Config: |001000010100>,  Probability: 0.0391%  (Count: 1)
#   Config: |010110110111>,  Probability: 0.0391%  (Count: 1)
#   Config: |010101110001>,  Probability: 0.0391%  (Count: 1)
#   Config: |100100010111>,  Probability: 0.0391%  (Count: 1)
#   Config: |011101101011>,  Probability: 0.0391%  (Count: 1)
#   Config: |100110101111>,  Probability: 0.0391%  (Count: 1)
#   Config: |010101101001>,  Probability: 0.0391%  (Count: 1)
#   Config: |011101100001>,  Probability: 0.0391%  (Count: 1)
#   Config: |011010100001>,  Probability: 0.0391%  (Count: 1)
#   Config: |011110010100>,  Probability: 0.0391%  (Count: 1)
#   Config: |001010010111>,  Probability: 0.0391%  (Count: 1)
#   Config: |010011011001>,  Probability: 0.0391%  (Count: 1)
#   Config: |101001010110>,  Probability: 0.0391%  (Count: 1)
#   Config: |000010111100>,  Probability: 0.0391%  (Count: 1)
#   Config: |011100001110>,  Probability: 0.0391%  (Count: 1)
#   Config: |000001110110>,  Probability: 0.0391%  (Count: 1)
#   Config: |101110101011>,  Probability: 0.0391%  (Count: 1)
#   Config: |101100100111>,  Probability: 0.0391%  (Count: 1)
#   Config: |101100001011>,  Probability: 0.0391%  (Count: 1)
#   Config: |010001100111>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001100111>,  Probability: 0.0391%  (Count: 1)
#   Config: |010111010011>,  Probability: 0.0391%  (Count: 1)
#   Config: |001010001010>,  Probability: 0.0391%  (Count: 1)
#   Config: |101010111110>,  Probability: 0.0391%  (Count: 1)
#   Config: |100011001100>,  Probability: 0.0391%  (Count: 1)
#   Config: |001100010011>,  Probability: 0.0391%  (Count: 1)
#   Config: |000100100011>,  Probability: 0.0391%  (Count: 1)
#   Config: |101101110001>,  Probability: 0.0391%  (Count: 1)
#   Config: |010110101011>,  Probability: 0.0391%  (Count: 1)
#   Config: |101101101011>,  Probability: 0.0391%  (Count: 1)
#   Config: |111011101100>,  Probability: 0.0391%  (Count: 1)
#   Config: |010000110101>,  Probability: 0.0391%  (Count: 1)
#   Config: |000110000001>,  Probability: 0.0391%  (Count: 1)
#   Config: |011011001101>,  Probability: 0.0391%  (Count: 1)
#   Config: |100101101011>,  Probability: 0.0391%  (Count: 1)
#   Config: |000010000011>,  Probability: 0.0391%  (Count: 1)
#   Config: |001001110110>,  Probability: 0.0391%  (Count: 1)
#   Config: |011111001110>,  Probability: 0.0391%  (Count: 1)
# total_probability= 100.0
#
# --- [最終的 config_str -> Count 映射字典] ---
# {'000110110111': 9, '001001001111': 9, '000111111111': 8, '001011110111': 8, '000111111101': 8, '001110111111': 7, '001111001111': 7, '001101101001': 7, '001001111111': 7, '001111000101': 7, '001011110011': 7, '001110011101': 7, '000101110111': 7, '001101001111': 7, '001111000111': 7, '000111101110': 7, '000111111001': 7, '000111010111': 7, '000111101111': 7, '001110101111': 7, '001100111101': 6, '001111110101': 6, '000110101111': 6, '000101101110': 6, '000101101111': 6, '001011111111': 6, '001111011010': 6, '001101011110': 6, '000101001111': 6, '001110111011': 6, '001111010111': 6, '001011101111': 6, '000111100011': 6, '000011101110': 6, '001011110110': 5, '001101110011': 5, '000111111011': 5, '001111100111': 5, '001100101111': 5, '001010110111': 5, '001010111111': 5, '000111001111': 5, '000110011111': 5, '001111101110': 5, '001101111011': 5, '000110001111': 5, '001001101110': 5, '000111011010': 5, '000111110110': 5, '001111011110': 5, '001101110110': 5, '001100101110': 5, '000111110111': 5, '001101011011': 5, '000110011101': 5, '001101011101': 5, '001101111101': 5, '000101111111': 5, '000111111110': 5, '001111011111': 5, '000100111110': 5, '000011101011': 5, '001111110110': 5, '001011010110': 5, '001010100111': 5, '000101100111': 5, '000001101111': 5, '001011010111': 5, '001000011111': 5, '001011101101': 5, '000111011110': 5, '000011100111': 5, '001110110110': 5, '001111010101': 5, '001010001111': 5, '001110011111': 5, '010111001101': 4, '001011100110': 4, '001101110111': 4, '001000101111': 4, '001100001111': 4, '001111001101': 4, '000111110101': 4, '001111001011': 4, '000101010111': 4, '001101001110': 4, '000011001111': 4, '000111011001': 4, '001000010111': 4, '000110001011': 4, '001100011111': 4, '001100011110': 4, '001001011111': 4, '001101010101': 4, '000110111001': 4, '001110111101': 4, '001100111111': 4, '000111111100': 4, '001011101011': 4, '000011000111': 4, '000111110011': 4, '000110111111': 4, '001101111010': 4, '001100001110': 4, '001110010100': 4, '000111100110': 4, '001000110100': 4, '000001111111': 4, '011101100011': 4, '001011111110': 4, '000010100011': 4, '001011001111': 4, '000101101011': 4, '001111001001': 4, '001110011011': 4, '000111011101': 4, '001001110100': 4, '000010111011': 4, '001100011101': 4, '001111110010': 4, '001110010101': 4, '000110101011': 4, '001110000101': 4, '000011111011': 4, '000110001001': 4, '001010110110': 4, '000011111111': 4, '000111010110': 4, '001110110101': 4, '001111111101': 4, '000111011100': 3, '001110001010': 3, '100011111011': 3, '001001010111': 3, '100011011111': 3, '100011111001': 3, '011101011111': 3, '010110110110': 3, '000101111011': 3, '001010111011': 3, '101000000011': 3, '001100001101': 3, '001110100011': 3, '010001111100': 3, '010011111010': 3, '001001101011': 3, '000001100011': 3, '001110101001': 3, '001111111111': 3, '001101110010': 3, '101110011111': 3, '001111111011': 3, '001110101010': 3, '101011001011': 3, '001100100101': 3, '001110110001': 3, '001110100110': 3, '001110100111': 3, '000110101110': 3, '011010110111': 3, '001011011110': 3, '001100111100': 3, '011110010001': 3, '001000001011': 3, '000100001011': 3, '000100110001': 3, '001100000101': 3, '010101101101': 3, '011110111111': 3, '101101001011': 3, '001101100110': 3, '001101010001': 3, '001110010111': 3, '000100010111': 3, '001111010010': 3, '000111100010': 3, '001110010011': 3, '001010011110': 3, '001110000111': 3, '001110101011': 3, '001001111011': 3, '000101111110': 3, '101100011101': 3, '010111001001': 3, '000101010110': 3, '011111001101': 3, '000111101001': 3, '001100101001': 3, '000011110101': 3, '000110110010': 3, '001111110100': 3, '001001011110': 3, '001110101101': 3, '000010111110': 3, '001011000111': 3, '001000111111': 3, '011010001001': 3, '001111101010': 3, '001011100011': 3, '001110001111': 3, '011010100011': 3, '001110001000': 3, '001000111011': 3, '000011011001': 3, '001101101110': 3, '000001001111': 3, '001100000111': 3, '000100001110': 3, '001100111010': 3, '000101110011': 3, '00111111 ...
#
# 字典 'final_config_str_dict' 中總共有 1445 個不重複的項目。

# %%
n_elec
# Out:
# (2, 2)

# %%
import collections


# --- 2. 守恆條件 ---
EXPECTED_N_ELEC = n_elec[0]+n_elec[1]
EXPECTED_S_Z_TIMES_2 = 0  # S_z * 2 (即 N_up - N_down)

# --- 3. 篩選 ---
conserved_states = collections.Counter()
total_samples = sum(config_counts.values())

for config_str, count in config_counts.items():
    
    # 檢查 N_elec
    if config_str.count('1') != EXPECTED_N_ELEC:
        continue # 電子數不符，跳過

    # 檢查 S_z (N_up - N_down)
    # 計算 "up" 自旋部分 (1up, 2up, 3up)
    n_up = sum(1 for i in range(0, len(config_str), 2) if config_str[i] == '1')  # 1up, 2up, 3up (索引 0, 2, 4...)
    # 計算 "down" 自旋部分 (1down, 2down)
    n_down = sum(1 for i in range(1, len(config_str), 2) if config_str[i] == '1')  # 1down, 2down (索引 1, 3, 5...)
    
    # 計算 S_z * 2 (up部分是+1，down部分是-1)
    current_s_z_times_2 = (n_up * 1) - (n_down * 1)
    
    # 檢查是否符合守恆條件
    if current_s_z_times_2 == EXPECTED_S_Z_TIMES_2:
        conserved_states[config_str] = count

total_conserved_count = sum(conserved_states.values())
conserved_prob = (total_conserved_count / total_samples) * 100
print(f"(總計: {total_conserved_count} / {total_samples} 樣本, 佔 {conserved_prob:.2f}%)")
print("-" * 40)

if not conserved_states:
    print("  (未發現任何符合條件的組態)")
else:
    # 使用 .most_common() 排序並列印
    for config, count in conserved_states.most_common():
        probability = (count / total_samples) * 100
        print(f"  |{config}> : {count:5} (Prob: {probability:5.2f}%)")

# 最終的守恆組態字典，將 "up" 和 "down" 的部分顯示成左邊是 "up" 右邊是 "down"
final_conserved_dict = {}

final_conserved_dict = {}

for config, count in conserved_states.items():
    # 將 config_str 重新排序為 'up' 部分在前，'down' 部分在後
    up_part = ''.join(config[i] for i in range(0, len(config), 2))  # "1up, 2up, 3up"
    down_part = ''.join(config[i] for i in range(1, len(config), 2))  # "1down, 2down"
    
    # 直接將 up_part 和 down_part 作為字典的鍵和值
    final_conserved_dict[(up_part+ down_part)] = count

print("\n--- [守恆組態的字典格式] ---")
print(final_conserved_dict)
# Out:
# (總計: 94 / 2560 樣本, 佔 3.67%)
# ----------------------------------------
#   |001000110100> :     4 (Prob:  0.16%)
#   |000110001001> :     4 (Prob:  0.16%)
#   |000001100011> :     3 (Prob:  0.12%)
#   |000100001011> :     3 (Prob:  0.12%)
#   |000100001110> :     3 (Prob:  0.12%)
#   |001100000110> :     3 (Prob:  0.12%)
#   |001000000111> :     3 (Prob:  0.12%)
#   |001100010010> :     2 (Prob:  0.08%)
#   |000110010010> :     2 (Prob:  0.08%)
#   |000110001100> :     2 (Prob:  0.08%)
#   |000100110010> :     2 (Prob:  0.08%)
#   |000000110110> :     2 (Prob:  0.08%)
#   |000111001000> :     2 (Prob:  0.08%)
#   |001100000011> :     2 (Prob:  0.08%)
#   |100000011100> :     2 (Prob:  0.08%)
#   |000110100001> :     2 (Prob:  0.08%)
#   |000010010110> :     2 (Prob:  0.08%)
#   |100100100100> :     1 (Prob:  0.04%)
#   |000001011010> :     1 (Prob:  0.04%)
#   |000000111100> :     1 (Prob:  0.04%)
#   |010010000011> :     1 (Prob:  0.04%)
#   |100101100000> :     1 (Prob:  0.04%)
#   |000001100110> :     1 (Prob:  0.04%)
#   |001001000110> :     1 (Prob:  0.04%)
#   |000100100110> :     1 (Prob:  0.04%)
#   |000011100100> :     1 (Prob:  0.04%)
#   |000011001100> :     1 (Prob:  0.04%)
#   |000001001110> :     1 (Prob:  0.04%)
#   |000010100101> :     1 (Prob:  0.04%)
#   |010110100000> :     1 (Prob:  0.04%)
#   |000100101100> :     1 (Prob:  0.04%)
#   |100000000111> :     1 (Prob:  0.04%)
#   |010010100001> :     1 (Prob:  0.04%)
#   |000011000110> :     1 (Prob:  0.04%)
#   |010110001000> :     1 (Prob:  0.04%)
#   |000000011011> :     1 (Prob:  0.04%)
#   |100100000110> :     1 (Prob:  0.04%)
#   |000101001010> :     1 (Prob:  0.04%)
#   |001100001001> :     1 (Prob:  0.04%)
#   |000010000111> :     1 (Prob:  0.04%)
#   |100001100100> :     1 (Prob:  0.04%)
#   |001100001100> :     1 (Prob:  0.04%)
#   |001001100001> :     1 (Prob:  0.04%)
#   |001110000100> :     1 (Prob:  0.04%)
#   |000010001101> :     1 (Prob:  0.04%)
#   |001010010100> :     1 (Prob:  0.04%)
#   |011000000011> :     1 (Prob:  0.04%)
#   |001000011001> :     1 (Prob:  0.04%)
#   |000100101001> :     1 (Prob:  0.04%)
#   |000000011110> :     1 (Prob:  0.04%)
#   |100000001101> :     1 (Prob:  0.04%)
#   |001011000100> :     1 (Prob:  0.04%)
#   |001111000000> :     1 (Prob:  0.04%)
#   |001001010010> :     1 (Prob:  0.04%)
#   |001001001100> :     1 (Prob:  0.04%)
#   |011001000010> :     1 (Prob:  0.04%)
#   |000010110100> :     1 (Prob:  0.04%)
#   |001001000011> :     1 (Prob:  0.04%)
#   |011011000000> :     1 (Prob:  0.04%)
#   |100101001000> :     1 (Prob:  0.04%)
#   |000111000010> :     1 (Prob:  0.04%)
#   |001001001001> :     1 (Prob:  0.04%)
#   |000000100111> :     1 (Prob:  0.04%)
#   |000110011000> :     1 (Prob:  0.04%)
#   |000011000011> :     1 (Prob:  0.04%)
#   |001100100001> :     1 (Prob:  0.04%)
#   |001001110000> :     1 (Prob:  0.04%)
#   |000100100011> :     1 (Prob:  0.04%)
#
# --- [守恆組態的字典格式] ---
# {'010100000110': 4, '001010010001': 4, '000101001001': 3, '000011010001': 3, '000011010010': 3, '010001010010': 3, '010001000011': 3, '010001010100': 2, '001001010100': 2, '001010010010': 2, '000101010100': 2, '000101000110': 2, '001010011000': 2, '010001010001': 2, '100010000110': 2, '001100010001': 2, '001001000110': 2, '100100010010': 1, '000011001100': 1, '000110000110': 1, '001001100001': 1, '100100011000': 1, '000101001010': 1, '010001001010': 1, '000101010010': 1, '001100001010': 1, '001010001010': 1, '000011001010': 1, '001100000011': 1, '001100110000': 1, '000110010010': 1, '100001000011': 1, '001100100001': 1, '001001001010': 1, '001010110000': 1, '000011000101': 1, '100001010010': 1, '000011011000': 1, '010010010001': 1, '001001000011': 1, '100100001010': 1, '010010010010': 1, '010100001001': 1, '011000010010': 1, '001010000011': 1, '011000000110': 1, '010001100001': 1, '010010000101': 1, '000110010001': 1, '000011000110': 1, '100010000011': 1, '011000001010': 1, '011000011000': 1, '010001001100': 1, '010010001010': 1, '010001101000': 1, '001100000110': 1, '010001001001': 1, '011000101000': 1, '100010011000': 1, '001001011000': 1, '010010001001': 1, '000101000011': 1, '001010010100': 1, '001001001001': 1, '010100010001': 1, '010100001100': 1, '000101010001': 1}

# %%
from qiskit_addon_sqd.counts import BitArray
bitstrings = list(final_conserved_dict.keys())
bitvalues = [int(b, 2) for b in bitstrings]

# 根據出現次數生成對應的數據
samples = []
for bitstring, count in final_conserved_dict.items():
    samples.extend([int(bitstring, 2)] * count)  # 重複出現的數字

# 找出 num_bits
num_bits = len(bitstrings[0])  # 假設所有的 bit 字串長度相同

# 將這些整數數據打包為 uint8 陣列
num_bytes = (num_bits + 7) // 8  # 每個 bit 字串的大小（以字節計算）

# 轉換為二進位字節串
data = b"".join(val.to_bytes(num_bytes, "big") for val in samples)
array = np.frombuffer(data, dtype=np.uint8)

# 假設你已經有 BitArray 類別（如前面提供的代碼）
# 你可以將這個數據轉換為 BitArray 類型
bit_array = BitArray(array.reshape(-1, num_bytes), num_bits=num_bits)

# 輸出結果
print(bit_array)
# Out:
# BitArray(<shape=(), num_shots=94, num_bits=12>)

# %%
from qiskit_addon_sqd.counts import BitArray
bitstrings = list(config_counts.keys())
bitvalues = [int(b, 2) for b in bitstrings]

# 根據出現次數生成對應的數據
samples = []
for bitstring, count in config_counts.items():
    samples.extend([int(bitstring, 2)] * count)  # 重複出現的數字

# 找出 num_bits
num_bits = len(bitstrings[0])  # 假設所有的 bit 字串長度相同

# 將這些整數數據打包為 uint8 陣列
num_bytes = (num_bits + 7) // 8  # 每個 bit 字串的大小（以字節計算）

# 轉換為二進位字節串
data = b"".join(val.to_bytes(num_bytes, "big") for val in samples)
array = np.frombuffer(data, dtype=np.uint8)

# 假設你已經有 BitArray 類別（如前面提供的代碼）
# 你可以將這個數據轉換為 BitArray 類型
bit_array = BitArray(array.reshape(-1, num_bytes), num_bits=num_bits)

# 輸出結果
print(bit_array)
# Out:
# BitArray(<shape=(), num_shots=2560, num_bits=12>)

# %%
n_elec
# Out:
# (2, 2)

# %%
from functools import partial
 
from qiskit_addon_sqd.fermion import (
    SCIResult,
    diagonalize_fermionic_hamiltonian,
    solve_sci_batch,
)
 
# SQD options
energy_tol = 1e-6
occupancies_tol = 1e-6
max_iterations = 5
 
# Eigenstate solver options
num_batches = 3
samples_per_batch = 100
symmetrize_spin = True
carryover_threshold = 1e-4
max_cycle = 200
 
# Pass options to the built-in eigensolver. If you just want to use the defaults,
# you can omit this step, in which case you would not specify the sci_solver argument
# in the call to diagonalize_fermionic_hamiltonian below.
sci_solver = partial(solve_sci_batch, spin_sq=0.0, max_cycle=max_cycle)
 
# List to capture intermediate results
result_history = []
 
 
def callback(results: list[SCIResult]):
    result_history.append(results)
    iteration = len(result_history)
    print(f"Iteration {iteration}")
    for i, result in enumerate(results):
        print(f"\tSubsample {i}")
        print(f"\t\tEnergy: {result.energy + nuclear_repulsion_energy}")
        print(
            f"\t\tSubspace dimension: {np.prod(result.sci_state.amplitudes.shape)}"
        )
 
 
result = diagonalize_fermionic_hamiltonian(
    hcore,
    eri,
    bit_array,
    samples_per_batch=samples_per_batch,
    norb=n_orb,
    nelec=n_elec,
    num_batches=num_batches,
    energy_tol=energy_tol,
    occupancies_tol=occupancies_tol,
    max_iterations=max_iterations,
    sci_solver=sci_solver,
    symmetrize_spin=symmetrize_spin,
    carryover_threshold=carryover_threshold,
    callback=callback,
    seed=12345,
)
# Out:
# Iteration 1
# 	Subsample 0
# 		Energy: -7.634167329314557
# 		Subspace dimension: 225
# 	Subsample 1
# 		Energy: -7.634167329314557
# 		Subspace dimension: 225
# 	Subsample 2
# 		Energy: -7.634167329314557
# 		Subspace dimension: 225
# Iteration 2
# 	Subsample 0
# 		Energy: -7.634167329314557
# 		Subspace dimension: 225
# 	Subsample 1
# 		Energy: -7.634167329314557
# 		Subspace dimension: 225
# 	Subsample 2
# 		Energy: -7.634167329314557
# 		Subspace dimension: 225
